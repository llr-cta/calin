# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
c = [0.2,.6,0.35]
f = figure(figsize(8,4))
a = f.add_axes((0,0,1,1),frame_on=False,xticks=[],yticks=[],clip_on=False)
a.axis((-0.01,1.02,-0.01,1.02))
a.add_patch(Rectangle((0,0),1,1,color='w',ec=c,lw=2))
a.add_patch(Rectangle((0,0.7),1,0.3,color=c))
#a.text(0.05,0.9,'IACT',verticalalignment='center',family='arial',fontsize='40',color='w')
dy = 0.015
a.text(0.5,0.83,'CALIBRATION',ha='center',va='center',fontsize='60',color='w',weight='bold')
a.text(0.025,0.475+dy,'RUN NO.',ha='left',va='bottom',fontsize='40',color=c)
a.add_line(Line2D((0.35,0.975),(0.475+dy,0.475+dy),color=c))
a.text(0.025,0.25+dy,'BY',ha='left',va='bottom',fontsize='40',color=c)
a.add_line(Line2D((0.13,0.45),(0.25+dy,0.25+dy),color=c))
a.text(0.475,0.25+dy,'DATE',ha='left',va='bottom',fontsize='40',color=c)
a.add_line(Line2D((0.675,0.975),(0.25+dy,0.25+dy),color=c))
a.text(0.025,0.025+dy,'DUE',ha='left',va='bottom',fontsize='40',color=c)
a.add_line(Line2D((0.2,0.65),(0.025+dy,0.025+dy),color=c))
#a.add_patch(Rectangle((0.8,0),0.2,0.2,color=c))
a.text(0.985,0.0,'calin',ha='right',va='bottom',fontsize='50',color=[0.0,0.0,0.45],style='italic',weight='bold')
gcf().savefig('../../../assets/calin.svg')
gcf().savefig('../../../assets/calin_200x100.png',dpi=25)
gcf().savefig('../../../assets/calin_400x200.png',dpi=50)
gcf().savefig('../../../assets/calin_800x400.png',dpi=100)
